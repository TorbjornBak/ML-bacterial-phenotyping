# %%
from esm.models.esmc import ESMC
from esm.sdk.api import ESMProtein, LogitsConfig

from esm.tokenization import EsmSequenceTokenizer

# %%
client = ESMC(use_flash_attn = True).from_pretrained("esmc_300m").to("cpu") # or "cpu"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 client = ESMC(use_flash_attn = True).from_pretrained("esmc_300m").to("cpu") # or "cpu"
#
# TypeError: ESMC.__init__() missing 4 required positional arguments: 'd_model', 'n_heads', 'n_layers', and 'tokenizer'

# %%
protein = ESMProtein(sequence="AAGTAGCATCGACTCGACBBGTBRRRPPHPPA")
protein_tensor = client.encode(protein)
print(protein_tensor)
logits_output = client.logits(
   protein_tensor, LogitsConfig(sequence=True, return_embeddings=True)
)
#print(logits_output)
# Out:
# ESMProteinTensor(sequence=tensor([ 0,  5,  5,  6, 11,  5,  6, 23,  5, 11, 23,  6,  5, 23, 11, 23,  6,  5,
#         23, 25, 25,  6, 11, 25, 10, 10, 10, 14, 14, 21, 14, 14,  5,  2]), structure=None, secondary_structure=None, sasa=None, function=None, residue_annotations=None, coordinates=None, potential_sequence_of_concern=False)

# %%
print(logits_output.embeddings[0][0])
print((logits_output.embeddings.shape))
# Out:
# tensor([ 8.5242e-03, -4.4012e-03, -2.1845e-04, -7.1784e-03, -1.0686e-02,
#          6.6724e-03, -4.7919e-03,  3.4240e-03,  9.8166e-03, -3.3481e-03,
#         -3.3828e-02, -6.9265e-03,  6.5063e-03,  3.6207e-04, -2.8425e-02,
#          2.2798e-03,  4.9271e-03, -1.6070e-02, -8.6766e-03, -2.4320e-03,
#          1.7611e-02, -1.5155e-02,  8.4571e-03,  2.7203e-01,  2.7138e-02,
#          2.9108e-03, -5.5778e-03, -4.4175e-03, -2.1362e-03, -4.4069e-03,
#         -4.0546e-04,  4.1158e-03, -1.9557e-03,  1.3882e-03, -1.5480e-02,
#         -9.3165e-03, -1.0259e-02,  9.8001e-04, -1.2685e-02, -9.1866e-04,
#         -6.6599e-03,  1.2179e-03, -1.2228e-02, -1.0615e-02,  1.7624e-03,
#          3.8502e-03, -1.5390e-03,  3.9951e-03, -6.2106e-03,  1.1406e-02,
#         -1.1237e-02,  2.4001e-03,  3.9686e-03,  1.1391e-02,  4.0986e-03,
#          5.5744e-03,  7.5867e-03, -1.0737e-02, -1.3587e-03,  1.2429e-02,
#         -2.4503e-03, -1.4892e-02, -3.2712e-03,  2.7860e-03,  5.2692e-03,
# ...
