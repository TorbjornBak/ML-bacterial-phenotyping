# %%
import pandas as pd
genome_summary_path = "../downloads/genome_summary"

genome_summary = pd.read_csv(genome_summary_path,sep='\t')
genome_summary
# Out:
#          genome_id                                        genome_name  \
# 0         469009.4          "'Brassica napus' phytoplasma strain TW1"
# 1        1309411.5     "'Deinococcus soli' Cha et al. 2014 strain N5"
# 2        1123738.3  "'Echinacea purpurea' witches'-broom phytoplas...
# 3         551115.6                            "'Nostoc azollae' 0708"
# 4        1856298.3  "'Osedax' symbiont bacterium Rs2_46_30_T18 str...
# ...            ...                                                ...
# 1059041  1131286.3               zeta proteobacterium SCGC AB-137-J06
# 1059042  1131287.3               zeta proteobacterium SCGC AB-602-C20
# 1059043  1131288.3               zeta proteobacterium SCGC AB-602-E04
# 1059044  1131289.3               zeta proteobacterium SCGC AB-604-B04
# 1059045  1131290.3               zeta proteobacterium SCGC AB-604-O16
#
#          taxon_id genome_status  genome_length  gc_content  contig_l50  \
# ...

# %% [markdown]
# ## Filtering genomes

# %%
## bacteria, gc content, l50, n50, checkm_completeness?, checkm_contamination?



# Filter rows where gc_content is between 25 and 75


# Filter extremely long sequences?

filtered_genome_summary = genome_summary[genome_summary['genome_status'] != 'Deprecated']
genome_list = filtered_genome_summary[0:10].genome_id.to_list()
# Out:
# [469009.4,
#  1309411.5,
#  1123738.3,
#  551115.6,
#  1856298.3,
#  1706000.3,
#  28901.2925,
#  28901.2926,
#  28901.2927,
#  28901.2928]

# %%
pd.read_table("../downloads/spire_v1_microntology.tsv")
# Out:
#                 SAMN15803493 PRJNA656796 terrestrial:soil
# 0                    SAMN15803493 PRJNA656796 terrestrial
# 1       SAMN15803493 PRJNA656796 host-associated:plant...
# 2       SAMN15803493 PRJNA656796 host-associated:plant...
# 3                SAMN15803493 PRJNA656796 host-associated
# 4       SAMN15803497 PRJNA656796 host-associated:plant...
# ...                                                   ...
# 510861  SAMEA104500068 PRJEB24557 host-associated:anim...
# 510862  SAMEA104500068 PRJEB24557 host-associated:anim...
# 510863  SAMEA104500068 PRJEB24557 host-associated:anim...
# 510864  SAMEA104500068 PRJEB24557 host-associated:anim...
# 510865          SAMEA104500068 PRJEB24557 host-associated
#
# [510866 rows x 1 columns]
